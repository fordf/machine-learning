# %%
import pandas as pd
import random
from datetime import datetime

# %%
some_dict = {
    'students': ['Claire', 'Marc', 'Rick', 'Julien', 'Amos'],
    'dankedy': [19, 2, 1012, -12, 31] 
}

# %%
df = pd.DataFrame(some_dict)
df
# Out:
#    dankedy students
# 0       19   Claire
# 1        2     Marc
# 2     1012     Rick
# 3      -12   Julien
# 4       31     Amos

# %%
df['dankedy']
# Out:
# 0      19
# 1       2
# 2    1012
# 3     -12
# 4      31
# Name: dankedy, dtype: int64

# %%
type(_)
# Out:
# pandas.core.series.Series

# %%
pd.Series([random.randint(0,50) for x in range(10)])
# Out:
# 0     9
# 1    22
# 2     7
# 3    40
# 4    38
# 5    48
# 6    40
# 7    12
# 8     7
# 9    46
# dtype: int64

# %%
fmt = '%b %d, %Y'
finances = {
    "Name": ["Pablo", "Marcel", "Lisa", "Joanne", "Gerry", 'Billy'],
    "Assets": [120000, 80000, 110000, 230000, 1000000, 1200],
    "Debts": [90000, 80000, 30000, 50000, 800000, 10],
    "Updated": [
    datetime.strptime("Jun 10, 2011", fmt),
    datetime.strptime("Dec 30, 2005", fmt),
    datetime.strptime("May 4, 2000", fmt),
    datetime.strptime("Feb 16, 2007", fmt),
    datetime.strptime("Feb 16, 2007", fmt),
    datetime.strptime("Feb 16, 2007", fmt),
    ],
    "Total Rating": [3.5, 2.5, 4.0, 5.0, 4.0, 5.0]
}

# %%
df = pd.DataFrame(finances)

# %%
df.Name
# Out:
# 0     Pablo
# 1    Marcel
# 2      Lisa
# 3    Joanne
# 4     Gerry
# 5     Billy
# Name: Name, dtype: object

# %%
df.iloc[0]
# Out:
# Assets                       120000
# Debts                         90000
# Name                          Pablo
# Total Rating                    3.5
# Updated         2011-06-10 00:00:00
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['Assets', 'Debts', 'Name', 'Total Rating', 'Updated'], dtype='object')

# %%
df[['Debts', "Assets"]]
# Out:
#     Debts   Assets
# 0   90000   120000
# 1   80000    80000
# 2   30000   110000
# 3   50000   230000
# 4  800000  1000000
# 5      10     1200

# %%
df[df.Debts > 50000]
# Out:
#     Assets   Debts    Name  Total Rating    Updated
# 0   120000   90000   Pablo           3.5 2011-06-10
# 1    80000   80000  Marcel           2.5 2005-12-30
# 4  1000000  800000   Gerry           4.0 2007-02-16

# %%
df[df.Debts < 50000]
# Out:
#    Assets  Debts   Name  Total Rating    Updated
# 2  110000  30000   Lisa           4.0 2000-05-04
# 5    1200     10  Billy           5.0 2007-02-16

# %%
df = pd.read_csv('boston_housing_data.csv', sep=',', header=None)
df
# Out:
#           0        1     2      3      4      5       6         7        8   \
# 0        NaN  0.00632  18.0   2.31  0.000  0.538   6.575   65.2000   4.0900
# 1        NaN  0.02731   0.0   7.07  0.000  0.469   6.421   78.9000   4.9671
# 2        NaN  0.02729   0.0   7.07  0.000  0.469   7.185   61.1000   4.9671
# 3        NaN  0.03237   0.0   2.18  0.000  0.458   6.998   45.8000   6.0622
# 4        NaN  0.06905   0.0   2.18  0.000  0.458   7.147   54.2000   6.0622
# 5        NaN  0.02985   0.0   2.18  0.000  0.458   6.430   58.7000   6.0622
# 6        NaN  0.08829  12.5   7.87  0.000  0.524   6.012   66.6000   5.5605
# 7        NaN  0.14455  12.5   7.87  0.000  0.524   6.172   96.1000   5.9505
# 8        NaN  0.21124  12.5   7.87  0.000  0.524   5.631  100.0000   6.0821
# 9        NaN  0.17004  12.5   7.87  0.000  0.524   6.004   85.9000   6.5921
# 10       NaN  0.22489  12.5   7.87  0.000  0.524   6.377   94.3000   6.3467
# ...

# %%
df.rename(columns={0:'NaN_col'}).drop('NaN_col', axis=1)
# Out:
#           1     2      3      4      5       6         7        8      9   \
# 0    0.00632  18.0   2.31  0.000  0.538   6.575   65.2000   4.0900    1.0
# 1    0.02731   0.0   7.07  0.000  0.469   6.421   78.9000   4.9671    2.0
# 2    0.02729   0.0   7.07  0.000  0.469   7.185   61.1000   4.9671    2.0
# 3    0.03237   0.0   2.18  0.000  0.458   6.998   45.8000   6.0622    3.0
# 4    0.06905   0.0   2.18  0.000  0.458   7.147   54.2000   6.0622    3.0
# 5    0.02985   0.0   2.18  0.000  0.458   6.430   58.7000   6.0622    3.0
# 6    0.08829  12.5   7.87  0.000  0.524   6.012   66.6000   5.5605    5.0
# 7    0.14455  12.5   7.87  0.000  0.524   6.172   96.1000   5.9505    5.0
# 8    0.21124  12.5   7.87  0.000  0.524   5.631  100.0000   6.0821    5.0
# 9    0.17004  12.5   7.87  0.000  0.524   6.004   85.9000   6.5921    5.0
# 10   0.22489  12.5   7.87  0.000  0.524   6.377   94.3000   6.3467    5.0
# 11   0.11747  12.5   7.87  0.000  0.524   6.009   82.9000   6.2267    5.0
# ...

# %%
# !pip install pandasql
# Out:
# ...
#     100% |████████████████████████████████| 5.1MB 101kB/s ta 0:00:011
# ...
# done
# done
# ...

# %%
import pandasql as sql

# %%
fmt = '%b %d, %Y'
finances = {
    "Name": ["Pablo", "Marcel", "Lisa", "Joanne", "Gerry", 'Billy'],
    "Assets": [120000, 80000, 110000, 230000, 1000000, 1200],
    "Debts": [90000, 80000, 30000, 50000, 800000, 10],
    "Updated": [
    datetime.strptime("Jun 10, 2011", fmt),
    datetime.strptime("Dec 30, 2005", fmt),
    datetime.strptime("May 4, 2000", fmt),
    datetime.strptime("Feb 16, 2007", fmt),
    datetime.strptime("Feb 16, 2007", fmt),
    datetime.strptime("Feb 16, 2007", fmt),
    ],
    "Total Rating": [3.5, 2.5, 4.0, 5.0, 2.0, 3.0]
}
fdf = pd.DataFrame(finances)

# %%
sql.sqldf('SELECT * FROM fdf GROUP BY [Total Rating]')
# Out:
#     Assets   Debts    Name  Total Rating                     Updated
# 0  1000000  800000   Gerry           2.0  2007-02-16 00:00:00.000000
# 1    80000   80000  Marcel           2.5  2005-12-30 00:00:00.000000
# 2     1200      10   Billy           3.0  2007-02-16 00:00:00.000000
# 3   120000   90000   Pablo           3.5  2011-06-10 00:00:00.000000
# 4   110000   30000    Lisa           4.0  2000-05-04 00:00:00.000000
# 5   230000   50000  Joanne           5.0  2007-02-16 00:00:00.000000
